# %% [markdown]
# # FIT5147 Assessment 2 - Data Exploration and Visualisation
# ## United States Health Inequality data pre-processing
#
# **Author: Graham Chester**
#
# **Date: 24-Mar-2018**
#
# This Jupyter notebook takes two main datasets (health by city, life expectancy by county), and two value-mapping datasets, and wrangles them into a single CSV file (health.csv) suitable for use by D3 visualisation.
#
# The datasets used are:
#
# 1) Center for Disease control 500 Cities health data, sourced from CDC 500 Cities portal: https://chronicdata.cdc.gov/500-Cities/500-Cities-Local-Data-for-Better-Health-2017-relea/6vp6-wxuq
#
# 2) Life Expectancy by income dataset, sourced from the Health Inequality Project https://healthinequality.org/data/
#
# 3) City to lat, long, FIPS mapping dataset, sourced from SimpleMaps https://simplemaps.com/data/us-cities)
#
# 4) Commuting Zone to FIPS mapping dataset, sourced from IPUMS census data https://usa.ipums.org/usa/volii/1990LMAascii.txt

# %% [markdown]
# ## Imports and convenient display settings

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import LinearSVC
import seaborn as sns

# %matplotlib inline

# set Jupyter to display ALL output from a cell (not just last output)
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# set pandas and numpy options to make print format nicer
pd.set_option('display.width',110); pd.set_option('display.max_columns',100)
pd.set_option('display.max_colwidth', 200); pd.set_option('display.max_rows', 500)
np.set_printoptions(linewidth=100, threshold=5000, edgeitems=10, suppress=True)

# %% [markdown]
# ## Read CDC 500 Cities health dataset, filter and reshape
# 1) Read dataset with only required fields (for performance as dataset is 230MB)
#
# 2) Clean up data types, names and filter for required rows
#
# 3) Rename columns with more information for better display in d3
#
# 4) Pivot so there is one row per city with many measure

# %%
# only read in the required columns as dataset is large
columns = ['StateAbbr','StateDesc','CityName','GeographicLevel','Data_Value','Data_Value_Type','PopulationCount',
           'CityFIPS','Short_Question_Text', 'Category', 'Measure']

health_R = pd.read_csv('data/500_Cities.csv', dtype={'CityFIPS': str}, usecols=columns, na_filter=True)

# change the United States total row so it behaves like a state when visualising
health_R.loc[health_R.StateDesc=='United States', "CityName"] = "United States"
health_R.loc[health_R.StateDesc=='United States', "StateDesc"] = "Average"
health_R.shape
# health_R.head(1)

# we only need non-adusted numbers, and only for cities not electoral areas
health_F = health_R[(health_R.Data_Value_Type=='Crude prevalence') & 
                    (health_R.GeographicLevel.isin(['City','US'])) ]
health_F.shape

# pivot so that we have columns for all the health measures, instead of a row for each
health_P = pd.pivot_table(health_F, values='Data_Value', index=['StateDesc', 'CityName'], 
                          columns=['Short_Question_Text'], aggfunc=np.sum).reset_index()
health_P.shape

# merge with fields from original dataset to get overall health row
health = pd.merge(health_P, health_F[['StateDesc','CityName','CityFIPS','PopulationCount']].drop_duplicates(),
                  how='left', on=['StateDesc','CityName'])
health.shape
# health.head(2)

# subjectively assign weights to each preventative measure (negative), unhealthy behaviour and health outcome
weights = {
           'Health Insurance':        6,
           'Arthritis':               3,
           'Binge Drinking':          6,
           'High Blood Pressure':     7,
           'Taking BP Medication':    3,
           'Cancer (except skin)':   10,
           'Current Asthma':          4,
           'Coronary Heart Disease': 10,
           'Annual Checkup':         -3,
           'Cholesterol Screening':  -3,
           'Colorectal Cancer Screening': -2,
           'COPD'                       : 10,
           'Core preventive services for older men':   -3,
           'Core preventive services for older women': -3,
           'Current Smoking':         7,
           'Dental Visit':           -1,
           'Diabetes':                8,
           'High Cholesterol':        6,
           'Chronic Kidney Disease':  8,
           'Physical Inactivity':     3,
           'Mammography':            -2,
           'Mental Health':           6,
           'Obesity':                 7,
           'Pap Smear Test':         -2,
           'Sleep < 7 hours':         2,
           'Physical Health':         5,
           'Stroke':                  9,
           'Teeth Loss':              1,
          }

# calculate health score for a city as a rating with 0 (worst) to 100 (best)
columns = list(health_F.Short_Question_Text.unique())
health['health_score'] = health[columns].mul(pd.Series(weights), axis=1).sum(axis=1)

health['health_score'] = health.health_score - health.health_score.min()
health['health_score'] = (98 * (1 - health.health_score / health.health_score.max()) +1).astype(int)

health['Health Insurance'] = 100 - health['Health Insurance']

# population should be integer
health['PopulationCount'] = health.PopulationCount.astype(int)
# health.head(2)
# Out:
# (810103, 11)
# (14028, 11)
# (501, 30)
# (501, 32)

# %% [markdown]
# ## Highest correlated Health Measures

# %%
dfcorr = health.corr().round(3)
df = pd.DataFrame()
for i, col1 in enumerate(dfcorr.columns):
    for j, col2 in enumerate(dfcorr.columns):
        df = df.append({'col1':col1, 'col2': col2, 'cor': dfcorr.iloc[i,j]}, ignore_index=True)
df = df[(df.cor!=1) & (df.col2!='health_score')& (df.col1!='health_score')]
df = df.drop_duplicates(subset='cor', keep='first')
df['abs_cor'] = np.abs(df.cor)
df = df.sort_values('abs_cor', ascending=False)
df = df.drop("abs_cor",axis=1).reset_index()
df
# Out:
#      index                                      col1                                      col2    cor
# 0      205                    Chronic Kidney Disease                                    Stroke  0.920
# 1      100                                      COPD                    Coronary Heart Disease  0.913
# 2      505                       High Blood Pressure                                    Stroke  0.904
# 3      325                    Coronary Heart Disease                                    Stroke  0.900
# 4      592                             Mental Health                           Physical Health  0.894
# 5      190                    Chronic Kidney Disease                    Coronary Heart Disease  0.884
# 6      115                                      COPD                                    Stroke  0.883
# 7      202                    Chronic Kidney Disease                           Physical Health  0.880
# 8      387                           Current Smoking                                Teeth Loss  0.878
# 9      442                                  Diabetes                           Physical Health  0.875
# 10      33                                 Arthritis                                      COPD  0.867
# 11     412                              Dental Visit                           Physical Health -0.862
# 12     102                                      COPD                           Current Smoking  0.861
# 13     316                    Coronary Heart Disease                       High Blood Pressure  0.855
# 14     685                           Physical Health                                    Stroke  0.853
# 15     436                                  Diabetes                       High Blood Pressure  0.842
# 16     623                                   Obesity                       Physical Inactivity  0.839
# 17     597                             Mental Health                                Teeth Loss  0.835
# 18     409                              Dental Visit                             Mental Health -0.834
# 19     317                    Coronary Heart Disease                          High Cholesterol  0.830
# 20     223               Colorectal Cancer Screening                              Dental Visit  0.826
# 21     106                                      COPD                       High Blood Pressure  0.818
# 22     443                                  Diabetes                       Physical Inactivity  0.814
# 23     322                    Coronary Heart Disease                           Physical Health  0.813
# 24     112                                      COPD                           Physical Health  0.811
# 25     249    Core preventive services for older men  Core preventive services for older women  0.809
# 26     196                    Chronic Kidney Disease                       High Blood Pressure  0.808
# 27     627                                   Obesity                                Teeth Loss  0.806
# 28      46                                 Arthritis                       High Blood Pressure  0.801
# 29     117                                      COPD                                Teeth Loss  0.798
# 30     777                                    Stroke                                Teeth Loss  0.794
# 31     683                           Physical Health                       Physical Inactivity  0.793
# 32     417                              Dental Visit                                Teeth Loss -0.791
# 33     314                    Coronary Heart Disease                                  Diabetes  0.790
# 34     380                           Current Smoking                                   Obesity  0.789
# 35      96                                      COPD                    Chronic Kidney Disease  0.783
# 36     413                              Dental Visit                       Physical Inactivity -0.780
# 37     404                              Dental Visit                                  Diabetes -0.778
# 38      26                            Annual Checkup                      Taking BP Medication  0.777
# 39      55                                 Arthritis                                    Stroke  0.774
# 40     379                           Current Smoking                             Mental Health  0.769
# 41     385                           Current Smoking                                    Stroke  0.762
# 42     506                       High Blood Pressure                      Taking BP Medication  0.760
# 43     383                           Current Smoking                       Physical Inactivity  0.755
# 44     497                       High Blood Pressure                          High Cholesterol  0.753
# 45     342                            Current Asthma                           Current Smoking  0.752
# 46     225               Colorectal Cancer Screening                          Health Insurance  0.751
# 47     500                       High Blood Pressure                                   Obesity  0.744
# 48     109                                      COPD                             Mental Health  0.742
# 49      47                                 Arthritis                          High Cholesterol  0.741
# 50      56                                 Arthritis                      Taking BP Medication  0.739
# 51     444                                  Diabetes                           Sleep < 7 hours  0.737
# 52     219               Colorectal Cancer Screening  Core preventive services for older women  0.734
# 53     503                       High Blood Pressure                       Physical Inactivity  0.732
# 54     502                       High Blood Pressure                           Physical Health  0.730
# 55     440                                  Diabetes                                   Obesity  0.728
# 56     447                                  Diabetes                                Teeth Loss  0.726
# 57     625                                   Obesity                                    Stroke  0.725
# 58     326                    Coronary Heart Disease                      Taking BP Medication  0.724
# 59     171                     Cholesterol Screening                            Pap Smear Test  0.723
# 60     197                    Chronic Kidney Disease                          High Cholesterol  0.719
# 61     349                            Current Asthma                             Mental Health  0.718
# 62     595                             Mental Health                                    Stroke  0.717
# 63     622                                   Obesity                           Physical Health  0.716
# 64     203                    Chronic Kidney Disease                       Physical Inactivity  0.715
# 65     107                                      COPD                          High Cholesterol  0.712
# 66     110                                      COPD                                   Obesity  0.711
# 67     507                       High Blood Pressure                                Teeth Loss  0.709
# 68     714                       Physical Inactivity                           Sleep < 7 hours  0.707
# 69     101                                      COPD                            Current Asthma  0.704
# 70     104                                      COPD                                  Diabetes  0.703
# 71     561                               Mammography                            Pap Smear Test  0.701
# 72     376                           Current Smoking                       High Blood Pressure  0.698
# 73     193                    Chronic Kidney Disease                              Dental Visit -0.697
# 74      42                                 Arthritis                           Current Smoking  0.696
# 75     312                    Coronary Heart Disease                           Current Smoking  0.692
# 76     410                              Dental Visit                                   Obesity -0.691
# 77     207                    Chronic Kidney Disease                                Teeth Loss  0.690
# 78     473                          Health Insurance                       Physical Inactivity -0.690
# 79     439                                  Diabetes                             Mental Health  0.685
# 80     415                              Dental Visit                                    Stroke -0.683
# 81     411                              Dental Visit                            Pap Smear Test  0.680
# 82     231               Colorectal Cancer Screening                            Pap Smear Test  0.678
# 83     199                    Chronic Kidney Disease                             Mental Health  0.676
# 84     684                           Physical Health                           Sleep < 7 hours  0.674
# 85     437                                  Diabetes                          High Cholesterol  0.673
# 86      36                                 Arthritis                    Chronic Kidney Disease  0.669
# 87     200                    Chronic Kidney Disease                                   Obesity  0.665
# 88     590                             Mental Health                                   Obesity  0.663
# 89     435                                  Diabetes                          Health Insurance -0.661
# 90      34                                 Arthritis                      Cancer (except skin)  0.658
# 91     472                          Health Insurance                           Physical Health -0.657
# 92     536                          High Cholesterol                      Taking BP Medication  0.656
# 93     232               Colorectal Cancer Screening                           Physical Health -0.656
# 94      16                            Annual Checkup                       High Blood Pressure  0.651
# 95     414                              Dental Visit                           Sleep < 7 hours -0.651
# 96     373                           Current Smoking                              Dental Visit -0.646
# 97     320                    Coronary Heart Disease                                   Obesity  0.646
# 98     776                                    Stroke                      Taking BP Medication  0.640
# 99     116                                      COPD                      Taking BP Medication  0.636
# 100    355                            Current Asthma                                    Stroke  0.628
# 101    532                          High Cholesterol                           Physical Health  0.625
# 102    283  Core preventive services for older women                              Dental Visit  0.623
# 103    218               Colorectal Cancer Screening    Core preventive services for older men  0.620
# 104     41                                 Arthritis                            Current Asthma  0.611
# 105    192                    Chronic Kidney Disease                           Current Smoking  0.610
# 106    224               Colorectal Cancer Screening                                  Diabetes -0.609
# 107    125                      Cancer (except skin)                     Cholesterol Screening  0.609
# 108    374                           Current Smoking                                  Diabetes  0.601
# 109    103                                      COPD                              Dental Visit -0.596
# 110     52                                 Arthritis                           Physical Health  0.595
# 111     57                                 Arthritis                                Teeth Loss  0.593
# 112    228               Colorectal Cancer Screening                               Mammography  0.591
# 113    292  Core preventive services for older women                           Physical Health -0.588
# 114    146                      Cancer (except skin)                      Taking BP Medication  0.587
# 115    195                    Chronic Kidney Disease                          Health Insurance -0.587
# 116    204                    Chronic Kidney Disease                           Sleep < 7 hours  0.586
# 117    384                           Current Smoking                           Sleep < 7 hours  0.584
# 118    470                          Health Insurance                                   Obesity -0.584
# 119    533                          High Cholesterol                       Physical Inactivity  0.582
# 120    350                            Current Asthma                                   Obesity  0.579
# 121    624                                   Obesity                           Sleep < 7 hours  0.578
# 122     50                                 Arthritis                                   Obesity  0.577
# 123    471                          Health Insurance                            Pap Smear Test  0.576
# 124     74                            Binge Drinking                                  Diabetes -0.574
# 125    163                     Cholesterol Screening                              Dental Visit  0.573
# 126    157                     Cholesterol Screening               Colorectal Cancer Screening  0.568
# 127    229               Colorectal Cancer Screening                             Mental Health -0.566
# 128    499                       High Blood Pressure                             Mental Health  0.563
# 129    206                    Chronic Kidney Disease                      Taking BP Medication  0.558
# 130    469                          Health Insurance                             Mental Health -0.557
# 131    313                    Coronary Heart Disease                              Dental Visit -0.550
# 132    114                                      COPD                           Sleep < 7 hours  0.550
# 133     44                                 Arthritis                                  Diabetes  0.545
# 134    284  Core preventive services for older women                                  Diabetes -0.544
# 135    406                              Dental Visit                       High Blood Pressure -0.543
# 136    289  Core preventive services for older women                             Mental Health -0.540
# 137    446                                  Diabetes                      Taking BP Medication  0.540
# 138     66                            Binge Drinking                    Chronic Kidney Disease -0.532
# 139    294  Core preventive services for older women                           Sleep < 7 hours -0.529
# 140    354                            Current Asthma                           Sleep < 7 hours  0.528
# 141    137                      Cancer (except skin)                          High Cholesterol  0.526
# 142    716                       Physical Inactivity                      Taking BP Medication  0.524
# 143    237               Colorectal Cancer Screening                                Teeth Loss -0.524
# 144    652                            Pap Smear Test                           Physical Health -0.520
# 145      1                            Annual Checkup                                 Arthritis  0.516
# 146     24                            Annual Checkup                           Sleep < 7 hours  0.511
# 147    591                             Mental Health                            Pap Smear Test -0.509
# 148    165                     Cholesterol Screening                          Health Insurance  0.508
# 149    477                          Health Insurance                                Teeth Loss -0.507
# 150     76                            Binge Drinking                       High Blood Pressure -0.505
# 151     53                                 Arthritis                       Physical Inactivity  0.504
# 152    353                            Current Asthma                       Physical Inactivity  0.500
# 153     82                            Binge Drinking                           Physical Health -0.499
# 154    187                    Chronic Kidney Disease               Colorectal Cancer Screening -0.498
# 155    311                    Coronary Heart Disease                            Current Asthma  0.497
# 156    285  Core preventive services for older women                          Health Insurance  0.496
# 157     85                            Binge Drinking                                    Stroke -0.495
# 158    386                           Current Smoking                      Taking BP Medication  0.492
# 159     25                            Annual Checkup                                    Stroke  0.490
# 160    169                     Cholesterol Screening                             Mental Health -0.490
# 161     23                            Annual Checkup                       Physical Inactivity  0.488
# 162    408                              Dental Visit                               Mammography  0.483
# 163    653                            Pap Smear Test                       Physical Inactivity -0.482
# 164    230               Colorectal Cancer Screening                                   Obesity -0.481
# 165     10                            Annual Checkup                    Coronary Heart Disease  0.479
# 166    377                           Current Smoking                          High Cholesterol  0.476
# 167      3                            Annual Checkup                                      COPD  0.475
# 168    657                            Pap Smear Test                                Teeth Loss -0.471
# 169    291  Core preventive services for older women                            Pap Smear Test  0.468
# 170     49                                 Arthritis                             Mental Health  0.465
# 171    127                      Cancer (except skin)               Colorectal Cancer Screening  0.459
# 172    234               Colorectal Cancer Screening                           Sleep < 7 hours -0.459
# 173    537                          High Cholesterol                                Teeth Loss  0.458
# 174    343                            Current Asthma                              Dental Visit -0.456
# 175     14                            Annual Checkup                                  Diabetes  0.454
# 176      5                            Annual Checkup                     Cholesterol Screening  0.453
# 177     70                            Binge Drinking                    Coronary Heart Disease -0.453
# 178     83                            Binge Drinking                       Physical Inactivity -0.452
# 179    254    Core preventive services for older men                                  Diabetes -0.442
# 180    262    Core preventive services for older men                           Physical Health -0.436
# 181    475                          Health Insurance                                    Stroke -0.431
# 182    201                    Chronic Kidney Disease                            Pap Smear Test -0.430
# 183     84                            Binge Drinking                           Sleep < 7 hours -0.422
# 184     12                            Annual Checkup                           Current Smoking  0.422
# 185     87                            Binge Drinking                                Teeth Loss -0.421
# 186    441                                  Diabetes                            Pap Smear Test -0.420
# 187    807                      Taking BP Medication                                Teeth Loss  0.419
# 188     77                            Binge Drinking                          High Cholesterol -0.419
# 189    468                          Health Insurance                               Mammography  0.415
# 190    177                     Cholesterol Screening                                Teeth Loss -0.410
# 191    135                      Cancer (except skin)                          Health Insurance  0.407
# 192     18                            Annual Checkup                               Mammography  0.403
# 193    474                          Health Insurance                           Sleep < 7 hours -0.401
# 194    176                     Cholesterol Screening                      Taking BP Medication  0.400
# 195     63                            Binge Drinking                                      COPD -0.400
# 196    407                              Dental Visit                          High Cholesterol -0.398
# 197    293  Core preventive services for older women                       Physical Inactivity -0.396
# 198    255    Core preventive services for older men                          Health Insurance  0.392
# 199    111                                      COPD                            Pap Smear Test -0.390
# 200      6                            Annual Checkup                    Chronic Kidney Disease  0.390
# 201    235               Colorectal Cancer Screening                                    Stroke -0.388
# 202     94                                      COPD                      Cancer (except skin)  0.386
# 203    655                            Pap Smear Test                                    Stroke -0.385
# 204    297  Core preventive services for older women                                Teeth Loss -0.384
# 205    259    Core preventive services for older men                             Mental Health -0.383
# 206    381                           Current Smoking                            Pap Smear Test -0.380
# 207    621                                   Obesity                            Pap Smear Test -0.378
# 208     27                            Annual Checkup                                Teeth Loss  0.378
# 209     79                            Binge Drinking                             Mental Health -0.375
# 210    128                      Cancer (except skin)    Core preventive services for older men  0.374
# 211    529                          High Cholesterol                             Mental Health  0.373
# 212    315                    Coronary Heart Disease                          Health Insurance -0.373
# 213     75                            Binge Drinking                          Health Insurance  0.372
# 214     17                            Annual Checkup                          High Cholesterol  0.370
# 215     54                                 Arthritis                           Sleep < 7 hours  0.367
# 216     81                            Binge Drinking                            Pap Smear Test  0.366
# 217    562                               Mammography                           Physical Health -0.364
# 218     20                            Annual Checkup                                   Obesity  0.363
# 219    321                    Coronary Heart Disease                            Pap Smear Test -0.358
# 220    375                           Current Smoking                          Health Insurance -0.356
# 221    222               Colorectal Cancer Screening                           Current Smoking -0.355
# 222    686                           Physical Health                      Taking BP Medication  0.352
# 223    136                      Cancer (except skin)                       High Blood Pressure  0.348
# 224    467                          Health Insurance                          High Cholesterol -0.348
# 225    534                          High Cholesterol                           Sleep < 7 hours  0.347
# 226    466                          Health Insurance                       High Blood Pressure -0.339
# 227    170                     Cholesterol Screening                                   Obesity -0.337
# 228    188                    Chronic Kidney Disease    Core preventive services for older men -0.334
# 229    133                      Cancer (except skin)                              Dental Visit  0.331
# 230    563                               Mammography                       Physical Inactivity -0.330
# 231    161                     Cholesterol Screening                            Current Asthma -0.329
# 232     32                                 Arthritis                            Binge Drinking -0.328
# 233    129                      Cancer (except skin)  Core preventive services for older women  0.327
# 234    288  Core preventive services for older women                               Mammography  0.325
# 235    261    Core preventive services for older men                            Pap Smear Test  0.320
# 236    560                               Mammography                                   Obesity -0.320
# 237    105                                      COPD                          Health Insurance -0.314
# 238    173                     Cholesterol Screening                       Physical Inactivity -0.313
# 239    172                     Cholesterol Screening                           Physical Health -0.312
# 240    746                           Sleep < 7 hours                      Taking BP Medication  0.309
# 241      4                            Annual Checkup                      Cancer (except skin)  0.308
# 242     80                            Binge Drinking                                   Obesity -0.305
# 243    220               Colorectal Cancer Screening                    Coronary Heart Disease -0.304
# 244     67                            Binge Drinking               Colorectal Cancer Screening  0.304
# 245    378                           Current Smoking                               Mammography -0.303
# 246    559                               Mammography                             Mental Health -0.301
# 247     86                            Binge Drinking                      Taking BP Medication -0.300
# 248    531                          High Cholesterol                            Pap Smear Test -0.294
# 249    198                    Chronic Kidney Disease                               Mammography -0.286
# 250    347                            Current Asthma                          High Cholesterol  0.285
# 251     11                            Annual Checkup                            Current Asthma  0.284
# 252    654                            Pap Smear Test                           Sleep < 7 hours -0.280
# 253    108                                      COPD                               Mammography -0.279
# 254    145                      Cancer (except skin)                                    Stroke  0.277
# 255     43                                 Arthritis                              Dental Visit -0.277
# 256    318                    Coronary Heart Disease                               Mammography -0.275
# 257    266    Core preventive services for older men                      Taking BP Medication  0.275
# 258     22                            Annual Checkup                           Physical Health  0.270
# 259     97                                      COPD               Colorectal Cancer Screening -0.268
# 260    280  Core preventive services for older women                    Coronary Heart Disease -0.266
# 261    351                            Current Asthma                            Pap Smear Test -0.265
# 262    141                      Cancer (except skin)                            Pap Smear Test  0.262
# 263    528                          High Cholesterol                               Mammography -0.255
# 264    226               Colorectal Cancer Screening                       High Blood Pressure -0.254
# 265    356                            Current Asthma                      Taking BP Medication  0.252
# 266    290  Core preventive services for older women                                   Obesity -0.251
# 267     21                            Annual Checkup                            Pap Smear Test  0.251
# 268    227               Colorectal Cancer Screening                          High Cholesterol -0.247
# 269     78                            Binge Drinking                               Mammography  0.245
# 270    263    Core preventive services for older men                       Physical Inactivity -0.239
# 271      2                            Annual Checkup                            Binge Drinking -0.234
# 272    126                      Cancer (except skin)                    Chronic Kidney Disease  0.234
# 273    158                     Cholesterol Screening    Core preventive services for older men  0.228
# 274    565                               Mammography                                    Stroke -0.225
# 275     69                            Binge Drinking  Core preventive services for older women  0.220
# 276     19                            Annual Checkup                             Mental Health  0.217
# 277    265    Core preventive services for older men                                    Stroke -0.216
# 278     71                            Binge Drinking                            Current Asthma -0.215
# 279     99                                      COPD  Core preventive services for older women -0.213
# 280     72                            Binge Drinking                           Current Smoking -0.207
# 281    438                                  Diabetes                               Mammography -0.205
# 282      7                            Annual Checkup               Colorectal Cancer Screening  0.200
# 283    281  Core preventive services for older women                            Current Asthma -0.199
# 284    144                      Cancer (except skin)                           Sleep < 7 hours -0.198
# 285     35                                 Arthritis                     Cholesterol Screening  0.197
# 286    501                       High Blood Pressure                            Pap Smear Test -0.189
# 287    286  Core preventive services for older women                       High Blood Pressure -0.188
# 288    282  Core preventive services for older women                           Current Smoking -0.186
# 289     68                            Binge Drinking    Core preventive services for older men  0.180
# 290    139                      Cancer (except skin)                             Mental Health -0.176
# 291    348                            Current Asthma                               Mammography -0.173
# 292    267    Core preventive services for older men                                Teeth Loss -0.169
# 293    596                             Mental Health                      Taking BP Medication  0.165
# 294     48                                 Arthritis                               Mammography -0.164
# 295    296  Core preventive services for older women                      Taking BP Medication  0.153
# 296    166                     Cholesterol Screening                       High Blood Pressure  0.141
# 297    221               Colorectal Cancer Screening                            Current Asthma -0.141
# 298    287  Core preventive services for older women                          High Cholesterol -0.140
# 299    167                     Cholesterol Screening                          High Cholesterol  0.139
# 300    416                              Dental Visit                      Taking BP Medication -0.125
# 301    156                     Cholesterol Screening                    Chronic Kidney Disease -0.122
# 302    143                      Cancer (except skin)                       Physical Inactivity -0.116
# 303      8                            Annual Checkup    Core preventive services for older men  0.115
# 304    164                     Cholesterol Screening                                  Diabetes -0.108
# 305     95                                      COPD                     Cholesterol Screening -0.106
# 306    345                            Current Asthma                          Health Insurance -0.101
# 307     51                                 Arthritis                            Pap Smear Test -0.100
# 308    250    Core preventive services for older men                    Coronary Heart Disease -0.090
# 309    175                     Cholesterol Screening                                    Stroke -0.087
# 310    138                      Cancer (except skin)                               Mammography  0.085
# 311      9                            Annual Checkup  Core preventive services for older women  0.082
# 312    498                       High Blood Pressure                               Mammography -0.082
# 313    256    Core preventive services for older men                       High Blood Pressure -0.074
# 314    260    Core preventive services for older men                                   Obesity -0.072
# 315     13                            Annual Checkup                              Dental Visit -0.069
# 316    566                               Mammography                      Taking BP Medication  0.068
# 317    140                      Cancer (except skin)                                   Obesity -0.058
# 318    132                      Cancer (except skin)                           Current Smoking  0.058
# 319     65                            Binge Drinking                     Cholesterol Screening  0.056
# 320    251    Core preventive services for older men                            Current Asthma -0.055
# 321     64                            Binge Drinking                      Cancer (except skin) -0.054
# 322    257    Core preventive services for older men                          High Cholesterol -0.047
# 323    808                      Taking BP Medication                           PopulationCount  0.046
# 324    656                            Pap Smear Test                      Taking BP Medication  0.042
# 325    131                      Cancer (except skin)                            Current Asthma  0.040
# 326    538                          High Cholesterol                           PopulationCount  0.039
# 327    148                      Cancer (except skin)                           PopulationCount  0.037
# 328    178                     Cholesterol Screening                           PopulationCount  0.035
# 329     45                                 Arthritis                          Health Insurance -0.034
# 330    160                     Cholesterol Screening                    Coronary Heart Disease  0.034
# 331     58                                 Arthritis                           PopulationCount  0.031
# 332    328                    Coronary Heart Disease                           PopulationCount  0.030
# 333    658                            Pap Smear Test                           PopulationCount  0.026
# 334    598                             Mental Health                           PopulationCount -0.024
# 335    134                      Cancer (except skin)                                  Diabetes  0.023
# 336     28                            Annual Checkup                           PopulationCount  0.022
# 337     37                                 Arthritis               Colorectal Cancer Screening  0.019
# 338    238               Colorectal Cancer Screening                           PopulationCount  0.018
# 339     98                                      COPD    Core preventive services for older men -0.018
# 340    252    Core preventive services for older men                           Current Smoking  0.017
# 341    358                            Current Asthma                           PopulationCount -0.015
# 342    448                                  Diabetes                           PopulationCount  0.013
# 343     39                                 Arthritis  Core preventive services for older women  0.012
# 344    118                                      COPD                           PopulationCount  0.010
# 345     88                            Binge Drinking                           PopulationCount -0.010
# 346     15                            Annual Checkup                          Health Insurance -0.009
# 347    478                          Health Insurance                           PopulationCount  0.009
# 348    388                           Current Smoking                           PopulationCount -0.008
# 349    778                                    Stroke                           PopulationCount  0.007
# 350    268    Core preventive services for older men                           PopulationCount  0.006
# 351    688                           Physical Health                           PopulationCount -0.005
# 352    298  Core preventive services for older women                           PopulationCount  0.005
# 353    838                                Teeth Loss                           PopulationCount  0.004
# 354    628                                   Obesity                           PopulationCount  0.000

# %% [markdown]
# ## Add City and county details to health dataframe for each city
# 1) Read US Cities data file.
#
# 2) Append latitude, longitude, county FIPS to the above health dataframe (so can be joined with life dataframe)

# %%
# read us cities data
uscities = pd.read_csv('data/uscitiesLatLongFIPS.csv', dtype={'PlaceFP':str, 'county_fips':str})
# uscities.head(2)

# reformat fields to not lose leading zeroes, and to corrent spelling of prefixes
uscities['county_fips'] = uscities.county_fips.apply('{:0>5}'.format)
uscities['city_ascii']  = uscities.city_ascii.str.replace('Saint', 'St.')

# merge city details with health dataframe
health = pd.merge(health, uscities[['city_ascii', 'state_name','lat','lng', 'county_fips','county_name']], 
                  how='left', left_on=['StateDesc','CityName'], right_on=['state_name','city_ascii'])

# change lat and long onUnited States row so d3 can place properly on screen
health.loc[health.CityName=='United States', 'lat'] =  51.1
health.loc[health.CityName=='United States', 'lng'] = -92.3
health.shape
# health.head(2)
# Out:
# (501, 39)

# %% [markdown]
# ## Read life expectancy by income dataset and pre-process
# 1) Read life expectancy by income range dataset
#
# 2) Rename colums for ease, and calculate various average life expectacies and disparity with income

# %%
# read into dataframe only the required columns
life = pd.read_csv('data/health_ineq_all_online_tables.csv', skiprows=6,
                   usecols=['cz','czname','statename','stateabbrv', 'le_agg_q1_F', 'le_agg_q2_F', 'le_agg_q3_F', 
                            'le_agg_q4_F', 'le_agg_q1_M', 'le_agg_q2_M', 'le_agg_q3_M', 'le_agg_q4_M', ])

# better names for colums for easier understanding in d3
life = life.rename(columns={'le_agg_q1_F': 'life_q1_f', 'le_agg_q2_F': 'life_q2_f', 
                            'le_agg_q3_F': 'life_q3_f', 'le_agg_q4_F': 'life_q4_f',
                            'le_agg_q1_M': 'life_q1_m', 'le_agg_q2_M': 'life_q2_m',
                            'le_agg_q3_M': 'life_q3_m', 'le_agg_q4_M': 'life_q4_m',})

# calculate average life expectancies for male, female, overall, and for top and bottom 25% income earners
life['expectancy_f'] = life[['life_q1_f', 'life_q2_f', 'life_q3_f', 'life_q4_f']].mean(axis=1).round(1)
life['expectancy_m'] = life[['life_q1_m', 'life_q2_m', 'life_q3_m', 'life_q4_m']].mean(axis=1).round(1)
life['expectancy_top25'] = (life['life_q4_f']/2 + life['life_q4_m']/2).round(1)
life['expectancy_bot25'] = (life['life_q1_f']/2 + life['life_q1_m']/2).round(1)
life['expectancy_avg'] = (life['expectancy_f']/2 + life['expectancy_m']/2).round(1)


# calculate the disparity in life expectancy between top and bottom income earners
life['disparity_m']  = (life['life_q4_m'] - life['life_q1_m']).round(1)
life['disparity_f']  = (life['life_q4_f'] - life['life_q1_f']).round(1)
life['disparity_avg']  = (life['expectancy_top25'] - life['expectancy_bot25']).round(1)
life = life.dropna(axis=0, how='all')
life.shape
# life.head(2)
# Out:
# (595, 20)

# %% [markdown]
# ## Add county FIPS code to life expectancy dataset
# 1) Read commuting zone to county FIPS mapping dataset
#
# 2) Add county FIPS code to life expectancy data
#
# 3) Drop non-required fields

# %%
cz_FIPS = pd.read_csv('data/1990LMAascii.csv',sep='\t', dtype={'FIPS': str})
cz_FIPS = cz_FIPS[cz_FIPS['County Name'] != 'Market Area Total']
cz_FIPS['stateabbrv'] = cz_FIPS['County Name'].str[-2:]
cz_FIPS.shape
# cz_FIPS.head(2)

# life = pd.merge(life, cz_FIPS, how='left', left_on=['stateabbrv','cz'], right_on=['stateabbrv','LMA/CZ'])
life = pd.merge(life, cz_FIPS, how='left', left_on=['cz'], right_on=['LMA/CZ'])
# life.head(1)
life = life.drop(['Total Population', 'Labor Force','County Name','LMA/CZ'], axis=1)
life.shape
# life.head(2)
# Out:
# (3141, 6)
# (2857, 22)

# %% [markdown]
# ## Merge health and life expectancy datasets
#
# 1) Merge datasets by county - note that city level life expectancy data was not available, however in most relevant cases US counties are small and cover one or just a few similar cities.
#
# 2) Calculate the mean life expectancies for the United States row
#
# 3) Save to CSV
#
# 4) Check for any NaN values (should just be the US overall row)

# %%
# merge health and life datasets by county FIPS code
total = pd.merge(health, life, how='left', left_on=['county_fips'], right_on=['FIPS'])
total = total.sort_values(['CityName','StateDesc'])
total.index.name = 'id'

# calculate mean life expectancy data for United States overall
usa_means = life.mean(axis=0) 
total.loc[total.CityName=='United States', usa_means.index[1:-1]] = np.round(usa_means[1:-1].values,1)
total.loc[total.CityName=='United States'] = total.loc[total.CityName=='United States'].fillna('')
total.shape
# total.head(3)

# rename columns to include more details for d3 to display
new_columns = {'Annual Checkup':                          '1P:No Annual Checkup', 
               'Cholesterol Screening':                   '1P:No Cholesterol Screening',
               'Colorectal Cancer Screening' :            '1P:No Colorectal Cancer Screening', 
               'Core preventive services for older men':  '1P:No Preventive services-older men',
               'Core preventive services for older women':'1P:No Preventive services-older women',
               'Dental Visit':                            '1P:No Dental Visit',
               'Health Insurance':                        '1P:No Health Insurance',
               'Mammography':                             '1P:No Mammography',
               'Pap Smear Test':                          '1P:No Pap Smear Test',
               'Taking BP Medication':                    '1P:Not Taking BP Medication',
               'Binge Drinking':         '2B:Binge Drinking',
               'Current Smoking':        '2B:Current Smoking',
               'Obesity':                '2B:Obesity',
               'Physical Inactivity':    '2B:Physical Inactivity',
               'Sleep < 7 hours':        '2B:Sleep < 7 hours',
               'Arthritis':              '3O:Arthritis',
               'COPD':                   '3O:Chronic Pulmonary Disease',
               'Cancer (except skin)':   '3O:Cancer',
               'Chronic Kidney Disease': '3O:Chronic Kidney Disease',
               'Coronary Heart Disease': '3O:Coronary Heart Disease',
               'Current Asthma':         '3O:Asthma',
               'Diabetes':               '3O:Diabetes',
               'High Blood Pressure':    '3O:High Blood Pressure',
               'High Cholesterol':       '3O:High Cholesterol',
               'Mental Health':          '3O:Mental Health',
               'Physical Health':        '3O:Physical Health',
               'Stroke':                 '3O:Stroke',
               'Teeth Loss':             '3O:All Teeth Lost',
               'expectancy_top25':  '4L:Life Expectancy Top 25%:Life expectancy in years, Top Quartile Income',
               'expectancy_bot25':  '4L:Life Expectancy Bot 25%:Life expectancy in years, Bottom Quartile Income',
               'expectancy_avg':    '4l:LIFE EXPECTANCY AVERAGE: Average Life Expectancy in Years',
                }
total = total.rename(columns=new_columns)

# rename columns to include detailed description as appended to the above column name
lookup = health_F[['Short_Question_Text','Measure']] \
                    .drop_duplicates().sort_values(['Short_Question_Text'])
lookup['Short_Question_Text'] = lookup.Short_Question_Text.map(new_columns)
lookup['Measure'] = lookup['Short_Question_Text'] + ':' + lookup.Measure
lookup = lookup.set_index('Short_Question_Text')['Measure'].to_dict()
total = total.rename(columns=lookup)

# Calculate overall preventative measure score by city
preventatives = total.columns[total.columns.str[1:3]=='P:']
for p in preventatives:  # reverse sign of preventative measures so ALL higher scores are bad
    total[p] = (100 - total[p]).round(1)
total['1p:PREVENTATIVE MEASURES AVG:Average of all preventative measures'] = total[preventatives].mean(axis=1).round(1)

# Calculate overall unhealthy behaviours score by city
behaviours = total.columns[total.columns.str[1:3]=='B:']
total['2b:UNHEALTHY BEHAVIOURS AVG:Average of all unhealty behaviours']   = total[behaviours].mean(axis=1).round(1)

# Calculate overall health outcomes score by city
outcomes = total.columns[total.columns.str[1:3]=='O:']
total['3o:HEALTH OUTCOMES AVG:Average of all health outcomes']     = total[outcomes].mean(axis=1).round(1)

# save to CSV file for d3
total.to_csv('health.csv')

# check for any rows with NaNs, should just be a few fields on the United States row
total[total.isnull().any(axis=1)]
# Out:
# (501, 61)
# Empty DataFrame
# Columns: [StateDesc, CityName, 1P:No Annual Checkup:Visits to doctor for routine checkup within the past Year among adults aged >=18 Years, 3O:Arthritis:Arthritis among adults aged >=18 Years, 2B:Binge Drinking:Binge drinking among adults aged >=18 Years, 3O:Chronic Pulmonary Disease:Chronic obstructive pulmonary disease among adults aged >=18 Years, 3O:Cancer:Cancer (excluding skin cancer) among adults aged >=18 Years, 1P:No Cholesterol Screening:Cholesterol screening among adults aged >=18 Years, 3O:Chronic Kidney Disease:Chronic kidney disease among adults aged >=18 Years, 1P:No Colorectal Cancer Screening:Fecal occult blood test, sigmoidoscopy, or colonoscopy among adults aged 50–75 Years, 1P:No Preventive services-older men:Older adult men aged >=65 Years who are up to date on a core set of clinical preventive services: Flu shot past Year, PPV shot ever, Colorectal cancer screening, 1P:No Preventive services-older women:Older adult women aged >=65 Years who are up to date on a core set of clinical preventive services: Flu shot past Year, PPV shot ever, Colorectal cancer screening, and Mammogram past 2 Years, 3O:Coronary Heart Disease:Coronary heart disease among adults aged >=18 Years, 3O:Asthma:Current asthma among adults aged >=18 Years, 2B:Current Smoking:Current smoking among adults aged >=18 Years, 1P:No Dental Visit:Visits to dentist or dental clinic among adults aged >=18 Years, 3O:Diabetes:Diagnosed diabetes among adults aged >=18 Years, 1P:No Health Insurance:Current lack of health insurance among adults aged 18–64 Years, 3O:High Blood Pressure:High blood pressure among adults aged >=18 Years, 3O:High Cholesterol:High cholesterol among adults aged >=18 Years who have been screened in the past 5 Years, 1P:No Mammography:Mammography use among women aged 50–74 Years, 3O:Mental Health:Mental health not good for >=14 days among adults aged >=18 Years, 2B:Obesity:Obesity among adults aged >=18 Years, 1P:No Pap Smear Test:Papanicolaou smear use among adult women aged 21–65 Years, 3O:Physical Health:Physical health not good for >=14 days among adults aged >=18 Years, 2B:Physical Inactivity:No leisure-time physical activity among adults aged >=18 Years, 2B:Sleep < 7 hours:Sleeping less than 7 hours among adults aged >=18 Years, 3O:Stroke:Stroke among adults aged >=18 Years, 1P:Not Taking BP Medication:Taking medicine for high blood pressure control among adults aged >=18 Years with high blood pressure, 3O:All Teeth Lost:All teeth lost among adults aged >=65 Years, CityFIPS, PopulationCount, health_score, city_ascii, state_name, lat, lng, county_fips, county_name, cz, czname, statename, stateabbrv_x, life_q1_f, life_q2_f, life_q3_f, life_q4_f, life_q1_m, life_q2_m, life_q3_m, life_q4_m, expectancy_f, expectancy_m, 4L:Life Expectancy Top 25%:Life expectancy in years, Top Quartile Income, 4L:Life Expectancy Bot 25%:Life expectancy in years, Bottom Quartile Income, 4l:LIFE EXPECTANCY AVERAGE: Average Life Expectancy in Years, disparity_m, disparity_f, disparity_avg, FIPS, stateabbrv_y, 1p:PREVENTATIVE MEASURES AVG:Average of all preventative measures, 2b:UNHEALTHY BEHAVIOURS AVG:Average of all unhealty behaviours, 3o:HEALTH OUTCOMES AVG:Average of all health outcomes]
# Index: []

# %%
col = '4l:LIFE EXPECTANCY AVERAGE: Average Life Expectancy in Years'
# col = '2B:Current Smoking:Current smoking among adults aged >=18 Years'
# col = '3O:Coronary Heart Disease:Coronary heart disease among adults aged >=18 Years'
# col = '3o:HEALTH OUTCOMES AVG:Average of all health outcomes'
# col = '2b:UNHEALTHY BEHAVIOURS AVG:Average of all unhealty behaviours'

temp = total[["CityName", "StateDesc", col]].sort_values(col).round(1)
temp.head()
temp.tail()

# temp1 = total.groupby("StateDesc").mean()
# temp1[[col]].sort_values(col).round(1)
# Out:
#          CityName  StateDesc  4l:LIFE EXPECTANCY AVERAGE: Average Life Expectancy in Years
# id
# 207      Columbus    Georgia                                                          81.0
# 320     Las Vegas     Nevada                                                          81.2
# 264  Lake Charles  Louisiana                                                          81.2
# 242       Hammond    Indiana                                                          81.2
# 241          Gary    Indiana                                                          81.2
#           CityName   StateDesc  4l:LIFE EXPECTANCY AVERAGE: Average Life Expectancy in Years
# id
# 480     Bellingham  Washington                                                          85.0
# 121    Santa Clara  California                                                          85.0
# 84   Mountain View  California                                                          85.0
# 80        Milpitas  California                                                          85.0
# 338       Santa Fe  New Mexico                                                          85.5

# %% [markdown]
# # Investigate data characteristics

# %%
print('Wealthy (quartile 4) Women live',round((total.life_q4_f - total.life_q1_f).mean(),1),
      ' years longer than poor (quartile 1) women')
print('Wealthy (quartile 4) Men   live',round((total.life_q4_m - total.life_q1_m).mean(),1),
      ' years longer than poor (quartile 1) men')
# Out:
# Wealthy (quartile 4) Women live 5.1  years longer than poor (quartile 1) women
# Wealthy (quartile 4) Men   live 7.9  years longer than poor (quartile 1) men

# %%
cols = np.append(total.columns[2:30].values, total.columns[46:59].values )

fig, axes = plt.subplots(nrows=14,ncols=3, figsize=(15,40))
for i, col in enumerate(cols):
    ax = axes[i//3,i%3]
    _ = ax.set_title(col[:40])
    _ = total.loc[:, col].plot(kind='hist', bins=80, ax=ax)
#     _ = total.loc[:, col].plot(kind='density',  ax=ax)
_ = plt.tight_layout()

# %%
import seaborn as sns
_ = sns.set(rc={'figure.figsize':(11,5)})
        
_ = sns.regplot(x='1p:PREVENTATIVE MEASURES AVG:Average of all preventative measures', y='4L:Life Expectancy Bot 25%:Life expectancy in years, Bottom Quartile Income', data=total)
_ = sns.regplot(x='1p:PREVENTATIVE MEASURES AVG:Average of all preventative measures', y='4L:Life Expectancy Top 25%:Life expectancy in years, Top Quartile Income', data=total)
_ = plt.ylabel('Life Expectancy top & bottom quartile incomes')
_ = plt.ylim((76,89))
_ = plt.title('Life expectancy versus Lack of preventative measures')
_ = plt.show()

_ = sns.regplot(x='2b:UNHEALTHY BEHAVIOURS AVG:Average of all unhealty behaviours', y='4L:Life Expectancy Bot 25%:Life expectancy in years, Bottom Quartile Income', data=total)
_ = sns.regplot(x='2b:UNHEALTHY BEHAVIOURS AVG:Average of all unhealty behaviours', y='4L:Life Expectancy Top 25%:Life expectancy in years, Top Quartile Income', data=total)
_ = plt.title('life expectancy versus Unhealthy behaviours')
_ = plt.ylabel('Life Expectancy top & bottom quartile incomes')
_ = plt.ylim((76,89))
_ = plt.show()

_ = sns.regplot(x='3o:HEALTH OUTCOMES AVG:Average of all health outcomes', y='4L:Life Expectancy Bot 25%:Life expectancy in years, Bottom Quartile Income', data=total)
_ = sns.regplot(x='3o:HEALTH OUTCOMES AVG:Average of all health outcomes', y='4L:Life Expectancy Top 25%:Life expectancy in years, Top Quartile Income', data=total)
_ = plt.title('life expectancy versus Health Outcomes(Problems)')
_ = plt.ylabel('Life Expectancy top & bottom quartile incomes')
_ = plt.ylim((76,89))
_ = plt.show()

# %%
pd.options.display.float_format = '{:.2f}'.format
cols = ['StateDesc','CityName', 'PopulationCount', 'health_score', 'expectancy_f', 'expectancy_m', 
        '4L:Life Expectancy Top 25%:Life expectancy in years, Top Quartile Income',
        '4L:Life Expectancy Bot 25%:Life expectancy in years, Bottom Quartile Income',
        '4l:LIFE EXPECTANCY AVERAGE: Average Life Expectancy in Years', 'disparity_avg', 
        '1p:PREVENTATIVE MEASURES AVG:Average of all preventative measures',
        '2b:UNHEALTHY BEHAVIOURS AVG:Average of all unhealty behaviours',
        '3o:HEALTH OUTCOMES AVG:Average of all health outcomes',
       ]
temp = total[cols].groupby('StateDesc').mean()
temp.sort_values('disparity_avg',ascending=False)

# %%
cols = ['CityName', 'StateDesc', 'PopulationCount', 'health_score', 'expectancy_f', 'expectancy_m', 
        '4L:Life Expectancy Top 25%:Life expectancy in years, Top Quartile Income',
        '4L:Life Expectancy Bot 25%:Life expectancy in years, Bottom Quartile Income',
        '4l:LIFE EXPECTANCY AVERAGE: Average Life Expectancy in Years', 'disparity_avg', 
        '1p:PREVENTATIVE MEASURES AVG:Average of all preventative measures',
        '2b:UNHEALTHY BEHAVIOURS AVG:Average of all unhealty behaviours',
        '3o:HEALTH OUTCOMES AVG:Average of all health outcomes',
       ]

temp = total.sort_values('3O:All Teeth Lost:All teeth lost among adults aged >=65 Years',ascending=False)
temp.head()
temp.tail()

# %%
import seaborn as sns

_ = sns.set(rc={'figure.figsize':(11,6)})
graphs = {'Binge Drinking Rate': '2B:Binge Drinking:Binge drinking among adults aged >=18 Years',
          'Smoking Rate':'2B:Current Smoking:Current smoking among adults aged >=18 Years',
          'Obesity Rate':'2B:Obesity:Obesity among adults aged >=18 Years',
          'Inactivity Rate':'2B:Physical Inactivity:No leisure-time physical activity among adults aged >=18 Years',
         }

for graph in graphs:
    _ = sns.regplot(x=graphs[graph], label='Top 25% Income',
                    y='4L:Life Expectancy Top 25%:Life expectancy in years, Top Quartile Income', data=total)
    _ = sns.regplot(x=graphs[graph], label='Bot 25% Income',
                    y='4L:Life Expectancy Bot 25%:Life expectancy in years, Bottom Quartile Income', data=total)
    _ = plt.title('Life Expectancy vs ' + graph)
    _ = plt.ylabel('Life Expectancy in Years')
    _ = plt.xlabel(graph + ' in Percent')
    _ = plt.legend()
    _ = plt.show()

# %%
dfcorr = total.corr()
_ = plt.figure(figsize=(19,19))
_ = sns.heatmap(dfcorr, annot=True, cmap='RdBu_r', annot_kws={"size": 8})
